# %% [markdown]
# <a href="https://colab.research.google.com/github/maddog19527/CS-660-Homeworks/blob/main/Homework_1_CS_660.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import sympy as smp
import matplotlib as mp
import matplotlib.pyplot as plt
import pandas as pd
import math
from math import sin, cos, tan, log, pi

x,y = smp.symbols('x y', real=True)
f=(3*x**2)+(3*x)+2
f_1=smp.sin(x)+smp.cos(x)
f_2=smp.exp(2*x)+smp.log(x)
f_3=(2*(x**3)+3*x)**5
f_4=(x**2+1)*(smp.exp(x))

dfdx=smp.diff(f,x)
dfdx_1=smp.diff(f_1,x)
dfdx_2=smp.diff(f_2,x)
dfdx_3=smp.diff(f_3,x)
dfdx_4=smp.diff(f_4,x)
print(dfdx)
print(dfdx_1)
print(dfdx_2)
print(dfdx_3)
print(dfdx_4)
# Out:
# 6*x + 3
# -sin(x) + cos(x)
# 2*exp(2*x) + 1/x
# (30*x**2 + 15)*(2*x**3 + 3*x)**4
# 2*x*exp(x) + (x**2 + 1)*exp(x)

# %%
import numpy as np
import scipy as sp
import sympy as smp
import matplotlib as mp
import matplotlib.pyplot as plt
import pandas as pd
import math
from math import sin, cos, tan, log, pi

x,y=smp.symbols('x y', real=True)
gradf=[f_y,f_x]

f_a=x**2+y**2+(2*x*y)
f_y=smp.diff(f_a,x)
f_x=smp.diff(f_a,y)
print(f_y)
print(f_x)
print(gradf)
# Out:
# 2*x + 2*y
# 2*x + 2*y
# [2*x + 2*y, 2*x + 2*y]

# %%
import numpy as np
import scipy as sp
import sympy as smp
import matplotlib as mp
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
import math

def yfunc(x):
  return x**4-4*x**2+4

def yderivative(x):
  return 4*x**3-8*x

x=np.arange(0,10,0.1)

y=yfunc(x)

start_pt=(1, yfunc(1))

learning_rate=0.1

for i in range(3):
 new_x = start_pt[0] - learning_rate * yderivative(start_pt[0])
 new_y = yfunc(new_x)
 start_pt=(new_x, new_y)
 print(new_x)
 plt.plot(x,y)
 plt.scatter(start_pt[0], start_pt[1], color='red')
 plt.pause(0.1)
 plt.clf()
# Out:
# 1.4
# 1.4224
# 1.4091877474304
